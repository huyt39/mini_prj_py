# %%
import matplotlib 
print (matplotlib.__version__)
# Out:
# 3.8.4

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
x1 = np.array([1, 8])
y1 = np.array([3, 10])

plt.plot(x1, y1)
plt.show()

# %%
x1 = np.array([1, 8])
y1 = np.array([3, 10])

plt.plot(x1, y1, 'o')
plt.show()

# %%
#Multiple points:
x2 = np.array([1, 2, 6, 8])
y2 = np.array([3, 8, 1, 10])

plt.plot(x2, y2)
plt.show()

# %%
#default x points:
y3 = np.array([3, 8, 1, 10, 5, 7])

plt.plot(y3)
plt.show()  #x default: 0, 1, 2...

# %%
#Matplot markers:
y4 = np.array([3, 8, 1, 10])

plt.plot(y4, marker = 'o')
plt.show()

# %%
plt.plot(y4, marker = '*')
plt.show()

# %%
#Format string fmt, syntax: marker|line|color
plt.plot(y4, 'o:r')
plt.show()

# %%
plt.plot(y4, 'o-b')
plt.show()

# %%
plt.plot(y4, 'o--g')
plt.show()

# %%
plt.plot(y4, 'o-.y')

# %%
#Marker size
plt.plot(y4, marker = 'o', ms = 20)
plt.show()

# %%
#marker color
plt.plot(y4, marker = 'o', ms = 15, mec = 'r')
plt.show()

# %%
plt.plot(y4, mec = 'g', ms = 10, marker = '*')
plt.show()

# %%
#color inside:
plt.plot(y4, marker = 'o', ms = 15, mfc = 'y')
plt.show()

# %%
plt.plot(y4, marker = 'o', ms = 20, mec = 'r', mfc = 'y')
plt.show()

# %%
plt.plot(y4, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
plt.plot(y4, marker = 'o', ms = 20, mec = 'Aqua', mfc = 'Aqua')
plt.show()

# %%
plt.plot(y4, marker = '*', ms = 20, mec = '#F0F8FF', mfc = '#F0F8FF')
plt.show()

# %%
#Line:
plt.plot(y4, linestyle = 'dotted')
plt.show()

# %%
plt.plot(y4, linestyle = 'dashed')
plt.show()

# %%
#Shorter syntax: linestyle = ls ; dotted=: ; dashed = --
plt.plot(y4, ls = ':')
plt.show()

# %%
#line color:
plt.plot(y4, color = 'g')
plt.show()

# %%
plt.plot(y4, c = '#4CAF50')
plt.show()

# %%
plt.plot(y4, c = 'hotpink')
plt.show()

# %%
plt.plot(y4, c = 'r', linewidth = '30')
plt.show()

# %%
#multiple lines
y1 = np.array([1, 2, 3, 4])
y2 = np.array([8, 4, 7, 3])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x5 = np.array([0, 1, 4, 3])
y5 = np.array([7, 6, 9, 2])
x6 = np.array([3, 5, 2, 1])
y6 = np.array([1, 7, 4, 8])

plt.plot(x5, y5, x6, y6)
plt.show()

# %%
#Labels and title

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.title ("Sports watch data")
plt.show()

# %%
#Font properties for title and labels:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue', 'size': 20}
font2 = {'family':'serif','color':'darkred', 'size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#Position the title:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#Grid:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis = 'x')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data", loc = 'right')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis = 'y') 
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis = 'both') #default
plt.show()

# %%
#Set line properties for the grid:
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#Multiple plots:
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1) #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x, y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40]) 
plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x, y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x, y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x, y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.plot(x, y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 2)
plt.plot(x, y)

#plot 3:
x = np.array([1, 3, 5, 7])
y = np.array([30, 50, 70, 90])
plt.subplot(2, 3, 3)
plt.plot(x, y)

#plot 4:
x = np.array([2, 4, 6, 8])
y = np.array([20, 40, 60, 80])
plt.subplot(2, 3, 4)
plt.plot(x, y)

#plot 5:
x = np.array([1, 4, 7, 9])
y = np.array([30, 40, 70, 80])
plt.subplot(2, 3, 5)
plt.plot(x, y)

#plot 6:
x = np.array([9, 8, 6, 3])
y = np.array([30, 60, 40, 35])
plt.subplot(2, 3, 6)
plt.plot(x, y)

plt.show()

# %%
#Title:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.title("SALES")

x = np.array([3, 4, 5, 6])
y = np.array([3, 8, 9, 10])
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.title("INCOME")

plt.show()

# %%
#Super title:
#Title:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.title("SALES")

x = np.array([3, 4, 5, 6])
y = np.array([3, 8, 9, 10])
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
#Scatter:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
#Compare plots:

#day 1, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day 2, the age and speed of 13 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()
#The result => conclusion: the newer car, the faster it drives

# %%
#Color
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

#day 2, the age and speed of 13 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
#Color each dot:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c = colors)


plt.show()

# %%
#Color map
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)
 
plt.show() #Size

# %%
#Adjust the transparency by alpha argument
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha = 0.5)

plt.show()

# %%
#Combine color size and alpha:
x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))
sizes = 10*np.random.randint(100, size = (100))

plt.scatter(x, y, c = colors, s = sizes, alpha = 0.5, cmap = 'nipy_spectral')

plt.colorbar()

plt.show()
